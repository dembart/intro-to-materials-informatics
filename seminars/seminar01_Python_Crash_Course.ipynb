# %% [markdown]
# ### Seminar #1: Python crash course

# %% [markdown]
# #### Goals
#
# Learning outcomes
#
# - manipulate data types in Python
# - vectorization in Python
# - read/write data with pandas
# - plotting with matplotlib
# - curve fit with scipy
#
# #### Agenda
# - python coding basics
#
#     - data types
#     - loops
#     - if/else
#     - objects and methods
#     - functions
# - intro to numpy
#     - vectorization
#     - lists vs. numpy arrays
# - intro to pandas
#     - read .csv
#     - dataframe
# - matplotlib
#     - plotting data
# - scipy
#     - curve_fit
#     - linear regression

# %% [markdown]
# #### Resources used to create this notebook
# - python basics: https://www.w3schools.com/python/default.asp
#
# - numpy, scipy: https://harvard-iacs.github.io/2018-CS109A/labs/lab-1/student/
#
# - [numpy beginner's guide](https://numpy.org/doc/stable/user/absolute_beginners.html)

# %% [markdown]
# ### Spoiler
# - By the end of this seminar you will be able to understand/reproduce/modify the following code

# %%
# !mkdir data
# !wget -O ./data/measured_data.csv https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/measured_data.csv ./data/
# Out:
# --2025-09-17 16:22:27--  https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/measured_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7467 (7,3K) [text/plain]
# Saving to: ‘./data/measured_data.csv’
#
# ./data/measured_dat 100%[===================>]   7,29K  --.-KB/s    in 0,007s
#
# 2025-09-17 16:22:28 (985 KB/s) - ‘./data/measured_data.csv’ saved [7467/7467]
#
# --2025-09-17 16:22:28--  http://./data/
# Resolving . (.)... failed: nodename nor servname provided, or not known.
# wget: unable to resolve host address ‘.’
# FINISHED --2025-09-17 16:22:28--
# Total wall clock time: 0,6s
# Downloaded: 1 files, 7,3K in 0,007s (985 KB/s)

# %%
import pandas as pd
import numpy as np
from scipy.optimize import curve_fit   
import matplotlib.pyplot as plt

# toy example data, contains two columns - 'x' and 'y'
# y is a measured response to a change in x
data = pd.read_csv('data/measured_data.csv') 

plt.rcParams.update({'font.size': 10})
fig, (ax1, ax2) = plt.subplots(dpi = 300, figsize = (6, 3), ncols = 2)

x = data['x']
y = data['y']

ax1.scatter(x, y, marker = 'o', label = 'measured', s = 3, alpha = 0.5)



def parabola(x, a0, a1, a2):
    return a0 + a1 * x + a2 * x**2

popt, pcov = curve_fit(parabola, x, y)

y_fit = parabola(x, *popt)
ax1.plot(x, y_fit, label = 'fit')

_ = ax2.hist(y - y_fit, bins = 20)

ax2.set_xlabel('Err')
ax2.set_ylabel('Count')

std = (y - y_fit).std()

ax1.fill_between(x, y_fit - std, y_fit + std, alpha = 0.25, color = 'darkred', label = '1 sigma')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()
plt.tight_layout()

# %% [markdown]
# #### Why learning python?
# - the most popular programming language in science
#
# - huge community
# - open-source solutions for almost every problem
# - simple syntax
# - automation (as any programming language)

# %% [markdown]
# ### Python basics

# %% [markdown]
# ##### Variables and operators
#
# Variables
# - Variables are containers for storing data values
#
# - Variables are created when you assign a data to it
#
# - Variable name must start with a letter or the underscore character
#
# - Comment line starts with #
#
# - Comment line is not executed
#
#
#
#
#
# Operators
# - Operators are used to perform operations with variables
# - "+"
# - "-"
# - '*'
# - "/"
# - "//"
# - "%"
# - "!="
# - "=="
# - "**"
# - ">", "<"
# - ...

# %%
# coment line 
# not executed
# because it starts with #


var = 1     # integer
var_ = '1'  # string
_var = 1.0  # float
var1 = 1e0  # float
var_1 = 1/1 # float #DA integer in older versions of Python
_1vAr_ = 1
_VaR1__________ = 1

# %% [markdown]
# If you do not follow the rules, the interpreter will throw an error.

# %%
1var = 1

# %% [markdown]
# - Variable naming is up to you
#
# - But it's recommended to follow the [PEP8](https://peps.python.org/pep-0008/) style guide

# %% [markdown]
# #### Built-in data types

# %% [markdown]
# - Text Type:	str
#
# - Numeric Types:	int, float, complex
# - Sequence Types:	list, tuple, range
# - Mapping Type:	dict
# - Set Types:	set, frozenset
# - Boolean Type:	bool
# - Binary Types:	bytes, bytearray, memoryview
# - None Type:	NoneType

# %% [markdown]
# ### Numbers
# - integer
# - float

# %%
integer_number = 42
floating_point_number = .97


x = 1
y = 2

x + y  # addition
x - y  # subtraction
x / y  # division
x * y  # multiplication
y ** 3 # exponentiation

10  + (10)**(1/2)

# %% [markdown]
# ### Strings

# %% [markdown]
# strings are defined with ```''```, ```""```, or ```""" """```

# %%
str_1 = 'My Name Is'
str_2 = "Slim Shady"

# %% [markdown]
# "+" operator concatenates the strings

# %%
str_1 + str_2

# %% [markdown]
# "*" operator concatenates a string with itself

# %%
str_1 * 5

# %% [markdown]
# There is a set of operators that works for specific data types. You cannot subtract one string from another

# %%
str_2 - str_1

# %% [markdown]
# ### Containers
# - lists
# - dictionaries
# - tuples

# %% [markdown]
# lists are defined with ```[]```

# %%
my_list = [1, 3, 4,]
my_list

# %% [markdown]
# You can store whatever you want in a list

# %%
my_list = [str_1, str_2, 0, 5.0]

# %%
new_list = [my_list, my_list] # list of lists

# %% [markdown]
# Similarly to strings, the "+" operator concatenates two lists

# %%
my_list + my_list

# %% [markdown]
# Similarly to strings, the "*" operator concatenates a list with itself

# %%
my_list * 3

# %%
my_list * 1.5

# %% [markdown]
# If you want to add two lists as two vectors, do it element-wise (will see it later)

# %% [markdown]
# dictionaries are defined with ```{key: value}```

# %%
key = 'student_name'
value = 'Sebastian Pereira'

my_dict = {key: value}
my_dict

# %%
my_dict = { 
          # key: value  
          'student_name': 'Sebastian Pereira',
           53: [0.3, 'some_string'],
           }

# %% [markdown]
# You can ask for a value from your dictionary using ```my_dict[key]```

# %%
key = 'student_name'
my_dict[key]

# %%
my_dict[53]

# %% [markdown]
# #### Indexing and slicing
# - numeration of the elements in python starts with 0

# %%
my_list = [1, 3, 4,]
my_list[0]

# %% [markdown]
# the last element of th list can be asked by -1 index

# %%
my_list[-1]

# %% [markdown]
# - for slicing use ":"

# %%
my_list[0:3]

# %% [markdown]
# indexing is a feature of a specific data types (structures)
# - lists, tuples, string

# %%
val = 1
val[0]

# %% [markdown]
# lists are mutable

# %%
my_list = [7, 12]
my_list[0] = -3
my_list

# %% [markdown]
# tuples are similar to lists, but immutable. these are defined with ()

# %%
my_tuple = (1, 2, 'f')

# %%
new_tuple = (my_tuple, my_tuple) # tuple of tuples

# %%
new_tuple[1] = 7.0

# %% [markdown]
# ### Objects and methods
#
# Python is an object oriented programming language. There are objects in python. For example, lists and dictionaries are the objects. There are specific methods defined for each type of objects.
#
#
# "Object-oriented programming (OOP) is a computer programming model that organizes software design around data, or objects, rather than functions and logic. An object can be defined as a data field that has unique attributes and behavior."
#
# [source](https://www.techtarget.com/searchapparchitecture/definition/object-oriented-programming-OOP)

# %%
my_list = [3, 5, 1, 5, 5, 5] # object

my_list.sort() # method

my_list

# %%
my_list = [3, 5, 1, 5, 5, 5] # object
 
my_list.count(5) # method

# %%
my_list = [3, 5, 1, 5, 5, 5] # object
 
my_list.append(5) # method

my_list.count(5) # method

# %%
my_dict = {'Toyota': 'Celica'} # object

my_dict.update({'Nissan': 'Skyline'}) # method

my_dict

# %%
string = '10, 20, 30, 40' # object
string.split(',') # method
# Out:
# ['10', ' 20', ' 30', ' 40']

# %% [markdown]
# #### Indentation, errors

# %%
1/0

# %% [markdown]
# We can handle errors with try/except construction

# %%
try:
    1/0 # indentation here
except:
    print('Error') # function

# %% [markdown]
# Indentation is used in python to indicate a block of a code (as seen above)
# - 4 spaces or 1 tabulation

# %% [markdown]
# #### Functions

# %% [markdown]
# - A function is a block of code which only runs when it is called.
#
# - You can pass data, known as Arguments, into a function.
#
# - A function can return single or several objects or variables (or nothing)
#
# [Resource link](https://www.w3schools.com/python/python_functions.asp)

# %% [markdown]
# There are built-in functions in python
#
# https://docs.python.org/3/library/functions.html

# %%
print('Hello World!')

# %%
type('Hello World!')

# %%
type(print)

# %%
float('-1.0')

# %%
int(float('-1.0'))

# %%
round(-0.14934, 3)

# %%
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]
len(my_list)

# %%
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]

sum(my_list)

# %%
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]
zip(my_list, my_list)

# %%
list(zip(my_list, my_list))

# %%
help(list)

# %% [markdown]
# - A function is defined using the ```def``` keyword:

# %%
def my_func(arg):
    """
    my first function
    
    returns a passed number - 1

    Params
    ------
    arg: data_type
        a comment about the input parameter

    Returns
    -------
    arg - 1
    """
    
    out = arg - 1
    return out



my_func(-50)

# %%
def nothing():
    """"
    this function does nothing
    which is achieved by the "pass" keyword


    the pass statement is used as a placeholder for future code.
    then the pass statement is executed, nothing happens, but you avoid getting an error when empty code is not allowed.

    """
    pass

nothing()

# %% [markdown]
# More python keywords
#
# https://www.w3schools.com/python/python_ref_keywords.asp

# %% [markdown]
# #### if/else and iterations

# %% [markdown]
# element-wise summation

# %%
list_1 = [0, 1, 2, 3]
list_2 = [3, 2, 1, 0]
list_sum = []

for item_1, item_2 in zip(list_1, list_2):
    item_3 = item_1 + item_2
    list_sum.append(item_3)
list_sum

# %%
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]
for element in my_list:
    if element == 42:
        pass
    else:
        continue # do nothing but go to the next iteration step

# %%
ids = []
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]
for i, element in enumerate(my_list):
    if element == 42:
        print(element)
        ids.append(i)
    else:
        continue # do nothing but go to the next iteration step

# %%
for index in ids:
    print(my_list[index])

# %%
my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]
for i in range(len(my_list)):
    element = my_list[i]
    if element == 42:
        print(i, 'gotcha')
    else:
        continue # do nothing but go to the next iteration step

# %% [markdown]
# #### Modules

# %% [markdown]
# There are modules in Python. Some are installed by default, some are not. You need to import a module before using its methods. Your code always goes after the imports.
#
# - to import a module in python use the following construction
#
# ```python
# import name_of_the_module
# ```
#
#
# - frequently modules in python consists of several parts (submodules) with a different functionality
#
# - sometimes you want to import only a part of the module
#
# ```python
# from module.submodule import some_name
# ```

# %%
import os # operating system interface

# print the current working directory
print(os.getcwd())

# %%
from os import getcwd 

# print the current working directory
print(getcwd())

# %% [markdown]
# ### Task 1
# - Write a function that finds a maximum element in a list and returns its index

# %%
def min_id(my_list):
    """
    this function find an inde of the largest number in a list

    Params
    ------
    my_list: list
    

    Returns
    ------
    an index of the largest element in a list
    """

    # your code here
    pass

# %% [markdown]
# #### Task 2
#
# - Write a function that returns the number of times an element appears in a list
#
# - Compare with the count() built-in function

# %%
def count(my_list, element):
    """
    this function returns the number of occurrences of an item in a list.

    Params
    ------
    my_list: list
    
    element: any data object
        an element to count

    Returns
    ------
    the number of occurrences of an item in a list
    """

    # your code here
    pass


my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]

count(my_list, 8) == my_list.count(8), count(my_list, 0) == my_list.count(0)

# %% [markdown]
# #### Task 3
#
# - Write a function that returns a dictionary containing unique elements as keys and their counters as values
# - Compare your solution with the collections.Counter function

# %%
from collections import Counter

def counter_dict(my_list):

    """
    this function returns a dictionary with the number of occurrences of unique items in a list.

    Params
    ------
    my_list: list
    
    element: any data object
        an element to count

    Returns
    ------
    dictionary with numebr of occurances of unique elements in a list
    
    """
    pass

my_list = [4, 8, 15, 16, 23, 42, 8, 15, 16, 23, 42, 15, 16, 23, 42]

# %% [markdown]
# #### Important note:
# In some cases, when you "link" two variables, changes to one may affect the other. This corresponds to lists and dicts and other mutable data types.

# %%
list_1 = [1, 3, 2]
list_2 = list_1 # this is just a new name to the same object in memory
list_2.sort()
list_1 == list_2

# %% [markdown]
# To avoid it, you need to "unlink" the variables

# %%
list_1 = [1, 3, 2]
list_2 = list_1.copy() # create a copy
list_2.sort()
list_1 == list_2

# %% [markdown]
# Use [x] * n with immutable x in your list as the resulting list will hold references to the x object.

# %%
x = [1, 3]
ls = [x]
data = ls * 3 
data

# %%
x[0] = 12
data

# %% [markdown]
# #### Read/Write text file

# %%
with open('new_file.txt', 'w') as file: #open(file_name, mode)
    line = 'x, y\n' # \n is used to go to the next line
    file.write(line)
    line2 = '10, 12\n'
    file.write(line2)
    line3 = '20, 24\n'
    file.write(line3)

with open('new_file.txt') as file:
    text = file.readlines()
    for line in text:
        print(line)
# Out:
# x, y
#
# 10, 12
#
# 20, 24

# %% [markdown]
# "r" - Read - Default value. Opens a file for reading, error if the file does not exist
#
# "a" - Append - Opens a file for appending, creates the file if it does not exist
#
# "w" - Write - Opens a file for writing, creates the file if it does not exist
#
# "x" - Create - Creates the specified file, returns an error if the file exist

# %% [markdown]
# ### Task 4
#
# - read file data/measured_data.csv
# - iterate over lines in the file
#
# - collect x,  y variables into lists

# %% [markdown]
# ### Numpy
#
# "NumPy is the fundamental package for scientific computing in Python. It is a Python library that provides a multidimensional array object, various derived objects (such as masked arrays and matrices), and an assortment of routines for fast operations on arrays, including mathematical, logical, shape manipulation, sorting, selecting, I/O, discrete Fourier transforms, basic linear algebra, basic statistical operations, random simulation and much more"
#
# [documentation](https://numpy.org/doc/stable/index.html)
#
# [beginner's guide](https://numpy.org/doc/stable/user/absolute_beginners.html)
#
# [additional resource](https://colab.research.google.com/github/ffund/ml-notebooks/blob/master/notebooks/1-python-numpy-tutorial.ipynb#scrollTo=6d444cd2-9cd7-4b1b-9471-b1f2938019a4)

# %% [markdown]
# numpy.array

# %%
# import
import numpy as np # np is used for a shorter notation and ease of use

# %%
array = np.array([0, 1, 2, 3, 4]) # one dimensional array (rank 1 array)
array

# %% [markdown]
# shape of an array

# %%
array.shape

# %% [markdown]
# its dimension

# %%
array.ndim

# %%
array = np.array([[1, 3, 3], [3, 5, 8]])
array

# %%
array.shape

# %%
array.ndim

# %% [markdown]
# slicing and indexing

# %%
data = np.array([1, 2, 3])

# %%
# first element of an array
data[0]

# %%
# slice of an array
data[0:2]

# %% [markdown]
# ![bg](https://numpy.org/doc/stable/_images/np_indexing.png)

# %% [markdown]
# arrays are mutable similarly to lists

# %%
data = np.array([9, 0, 1])
data[1] = 1
data

# %% [markdown]
# select a subset of arrays that fulfills a specified conditions

# %%
data = np.array([i for i in range(10)])
data

# %%
data[data < 5]

# %% [markdown]
# stacking

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
np.hstack([a, b]) # horizontal stacking

# %%
np.vstack([a, b]) # vertical stacking

# %% [markdown]
# add element(s)

# %%
a = np.array([1, 2])
np.concatenate((a, [1, 3, 10]))

# %% [markdown]
# reshaping

# %%
data = np.array([1, 2, 3, 4])
data.reshape(2, 2)

# %%
data.reshape(2, 4)

# %% [markdown]
# creating basic arrays

# %%
ones = np.ones(8)
ones

# %%
zeros = np.zeros(8)
zeros

# %%
integer_sequence = np.arange(5, 18, 3)
integer_sequence

# %%
np.linspace(0, 10, 50) # linearly spaced values

# %% [markdown]
# basic operations with numpy arrays

# %%
a = np.ones(3)
b = np.ones(3) * 5 # broadcasting
b[-1] = 0.3

# %% [markdown]
# ![bg](https://numpy.org/doc/stable/_images/np_multiply_broadcasting.png)

# %%
a + b

# %%
a * b

# %%
a / b

# %%
a[0] = 0 
b / a

# %% [markdown]
# sorting

# %%
a = [5, 3, 8, 6, 1, 0]
np.array(a)

# %%
a.sort()
a

# %% [markdown]
# useful operations

# %%
data = np.array([0, 4, 6, 9, 2, 4])

# %%
data.min()

# %%
data.max()

# %%
data.mean()

# %%
data.sum()

# %%
data = np.array([[1, 2], [5, 3], [4, 6]])

# %%
data.max(axis = 0)

# %% [markdown]
# ![bg](https://numpy.org/doc/stable/_images/np_matrix_aggregation_row.png)

# %%
data.max(axis = 1)

# %% [markdown]
# operations with matrices and vectors

# %%
I = np.identity(3)
M = np.array([[2, 3, 1], [1, 0, 1], [0, 0, 1]])

# %%
# element-wise multiplication
I * M

# %%
np.multiply(I, M) # same thing

# %%
# dot product
np.dot(I, M)

# %%
I @ M # same thing

# %%
vector = np.array([1, 0, 2])
np.dot(vector, M)

# %%
np.dot(M, vector) # note the difference, order matters

# %%
# cross product of two vectors
v1 = np.array([1, 2, 3])
v2 = np.array([2, 1, 1])
np.cross(v1, v2)

# %%
# transpose 
M.T

# %% [markdown]
# ```np.linalg``` is used for linear algebra operations

# %%
# inverse matrix
np.linalg.inv(M)

# %%
v = np.array([0, 4, 8])
np.linalg.norm(v) # norm of a vector

# %%
np.linalg.norm(M, axis = 1) # norm along the axis

# %% [markdown]
# ### Task 5: Volume of a parallelepiped
#
# Write a function that calculates a volume of the parallepiped determined by three vectors
#
# Hint: Mixed dot product

# %%
def volume(v1, v2, v3):
    """
    This function calculates volume of 
    the parallepiped determined by three vectors

    Prameters
    --------
    v1: np.array
    v2: np.array
    v3: np.array

    Returns
    -------
    volume of a parallelepiped

    """


    pass

# %% [markdown]
# ### Matplotlib
# "Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible."
# [documentation](https://matplotlib.org/)

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# basic plot

# %%
x = np.linspace(0, 10, 20)
y = np.sin(x)

plt.plot(x, y)

# %% [markdown]
# subplots (provides more flexibility)

# %%
fig, ax = plt.subplots() # create figure and axis

ax.plot(x, y)
ax.plot(x, y/2)
ax.plot(x, y/4)
ax.plot(x, y/8)

# %%
fig, (ax1, ax2) = plt.subplots(dpi = 150, ncols = 2, figsize = (6, 3)) # figure with 150 dpi resolution, 2 horizontal subplots

ax1.plot(x, y)
ax2.plot(x, -y)

# %%
fig, axes = plt.subplots(dpi = 150, ncols = 2, figsize = (6, 3)) # same thing

axes[0].plot(x, y)
axes[1].plot(x, -y)

# %% [markdown]
# plot adjustments and annotation

# %%
fig, ax = plt.subplots(dpi = 150, ncols = 1, figsize = (6, 2)) 

ax.plot(x, y, label = 'sin(x)')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('y = sin(x)')
ax.grid()

ax.set_xlim(0, 10)
ax.set_ylim(-1, 1)
ax.legend()

# %% [markdown]
# plot a histogram

# %%
x = np.random.normal(size = 10000, loc = 0.5, scale = 0.1) # Draw random samples from a normal (Gaussian) distribution

fig, ax = plt.subplots(dpi = 150)
_ = ax.hist(x, bins = 100)

ax.set_title('normal distribution')
ax.set_xlabel('x label')
ax.set_ylabel('Count')

# %% [markdown]
# plot a scatter plot

# %%
x = np.random.normal(size = 10000, loc = 0.5, scale = 0.1) # Draw random samples from a normal (Gaussian) distribution
y = np.random.normal(size = 10000, loc = 0.5, scale = 0.1) # Draw random samples from a normal (Gaussian) distribution
colors = np.linspace(0, 1, len(x))

fig, ax = plt.subplots(dpi = 200, figsize = (3, 3))
ax.scatter(x, y, s = 10, marker = 'x', alpha = 0.5, c = colors)

ax.set_xlabel('x label')
ax.set_ylabel('y label')

plt.tight_layout()

# %% [markdown]
# ### Pandas
# "pandas is a fast, powerful, flexible and easy to use open source data analysis and manipulation tool,
# built on top of the Python programming language."
#
# [documentation](https://pandas.pydata.org/docs/)
# [getting started](https://pandas.pydata.org/docs/getting_started/index.html#getting-started)

# %%
import pandas as pd # pd is used for a shorter notation and ease of use

# %% [markdown]
# Pandas DataFrame is the main object of manipulation. Think of it as a table.
#
# ![bg](https://pandas.pydata.org/docs/_images/01_table_dataframe.svg)

# %% [markdown]
# create a DataFrame

# %%
first_names = ['John', 'Ivan', 'Stan']
df = pd.DataFrame(data = first_names, columns = ['first_name'])
df

# %% [markdown]
# add column

# %%
second_names = ['Doe', 'Ivanov', 'Smith']
df['second_name'] = second_names

# %%
df

# %% [markdown]
# concatenate two dataframes

# %%
df_new = pd.concat([df, df])

# %% [markdown]
# get column names

# %%
df_new.columns

# %% [markdown]
# query column elements

# %%
df_new['first_name']

# %% [markdown]
# query raw elements by integer index (similarly to the slicing of numpy arrays)

# %%
df_new.iloc[1]

# %% [markdown]
# query raw elements by index label

# %%
df_new.loc[1]

# %% [markdown]
# reset index labels

# %%
df_new.reset_index(drop = True)

# %% [markdown]
# get info about the dataframe

# %%
df_new.info()

# %% [markdown]
# reading data with pandas

# %% [markdown]
# ![bg](https://pandas.pydata.org/docs/_images/02_io_readwrite.svg)

# %% [markdown]
# read .csv file

# %%
# !mkdir data
# !wget -O ./data/bandgap_data_Na-P-S.csv https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/bandgap_data_Na-P-S.csv
# !wget -O ./data/energy_per_atom_data_Na-P-S.csv https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/energy_per_atom_data_Na-P-S.csv
# Out:
# mkdir: data: File exists
# --2025-09-17 16:25:36--  https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/bandgap_data_Na-P-S.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1987 (1,9K) [text/plain]
# Saving to: ‘./data/bandgap_data_Na-P-S.csv’
#
# ./data/bandgap_data 100%[===================>]   1,94K  --.-KB/s    in 0s
#
# 2025-09-17 16:25:37 (12,8 MB/s) - ‘./data/bandgap_data_Na-P-S.csv’ saved [1987/1987]
#
# --2025-09-17 16:25:37--  https://raw.githubusercontent.com/dembart/intro-to-materials-informatics/refs/heads/main/data/seminar01/energy_per_atom_data_Na-P-S.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2877 (2,8K) [text/plain]
# Saving to: ‘./data/energy_per_atom_data_Na-P-S.csv’
#
# ./data/energy_per_a 100%[===================>]   2,81K  --.-KB/s    in 0s
#
# 2025-09-17 16:25:38 (10,5 MB/s) - ‘./data/energy_per_atom_data_Na-P-S.csv’ saved [2877/2877]

# %%
data1 = pd.read_csv('data/bandgap_data_Na-P-S.csv')
data2 = pd.read_csv('data/energy_per_atom_data_Na-P-S.csv')

# %%
data1.head(5) # show first 5 entries
# Out:
#   material_id  band_gap chemsys
# 0    mp-10172       0.0      Na
# 1  mp-1079952       0.0      Na
# 2  mp-1186040       0.0      Na
# 3  mp-1186055       0.0      Na
# 4  mp-1186081       0.0      Na

# %%
data1.tail(5) # show last 5 entries
# Out:
#    material_id  band_gap chemsys
# 90      mp-612    2.4974     P-S
# 91  mp-1101885    2.6345  Na-P-S
# 92    mp-28782    2.2919  Na-P-S
# 93   mp-985584    2.2883  Na-P-S
# 94  mp-1189520    1.9880  Na-P-S

# %%
data2.head(5)
# Out:
#   material_id formula_pretty  energy_per_atom
# 0    mp-10172             Na        -3.564181
# 1  mp-1079952             Na        -3.477869
# 2  mp-1186040             Na        -3.540523
# 3  mp-1186055             Na        -3.537864
# 4  mp-1186081             Na        -3.544985

# %% [markdown]
# merge two tables

# %%
data = data1.merge(data2)

# %%
data
# Out:
#    material_id  band_gap chemsys formula_pretty  energy_per_atom
# 0     mp-10172    0.0000      Na             Na        -3.564181
# 1   mp-1079952    0.0000      Na             Na        -3.477869
# 2   mp-1186040    0.0000      Na             Na        -3.540523
# 3   mp-1186055    0.0000      Na             Na        -3.537864
# 4   mp-1186081    0.0000      Na             Na        -3.544985
# ..         ...       ...     ...            ...              ...
# 90      mp-612    2.4974     P-S             PS        -8.668890
# 91  mp-1101885    2.6345  Na-P-S         Na2PS3        -4.504702
# 92    mp-28782    2.2919  Na-P-S         Na3PS4        -4.368619
# 93   mp-985584    2.2883  Na-P-S         Na3PS4        -4.361498
# 94  mp-1189520    1.9880  Na-P-S          NaPS3        -4.699815
#
# [95 rows x 5 columns]

# %% [markdown]
# sort table by a given column

# %%
data_sorted = data.sort_values(by = 'energy_per_atom')
data_sorted
# Out:
#    material_id  band_gap chemsys formula_pretty  energy_per_atom
# 24   mp-568348    1.8454       P              P        -9.002076
# 19  mp-1198724    1.9259       P              P        -8.999905
# 22      mp-157    0.0104       P              P        -8.981862
# 14  mp-1014013    0.8832       P              P        -8.948089
# 15  mp-1094075    1.3059       P              P        -8.915710
# ..         ...       ...     ...            ...              ...
# 3   mp-1186055    0.0000      Na             Na        -3.537864
# 1   mp-1079952    0.0000      Na             Na        -3.477869
# 13   mp-999501    0.0000      Na             Na        -3.440211
# 5   mp-1221597    0.2698      Na             Na        -3.153397
# 8    mp-689577    0.0000      Na             Na        -2.480443
#
# [95 rows x 5 columns]

# %% [markdown]
# group data by some column and apply some operation to the resulting groups

# %%
data_grouped = data_sorted.groupby('formula_pretty').first()
data_grouped
# Out:
#                material_id  band_gap chemsys  energy_per_atom
# formula_pretty
# Na                mp-10172    0.0000      Na        -3.564181
# Na2PS3          mp-1101885    2.6345  Na-P-S        -4.504702
# Na2S                mp-648    2.4399    Na-S        -6.323377
# Na2S5             mp-28127    1.7772    Na-S        -7.364454
# Na3P               mp-1598    0.4033    Na-P        -5.385259
# Na3P11              mp-473    1.8326    Na-P        -8.135392
# Na3PS4            mp-28782    2.2919  Na-P-S        -4.368619
# NaP                mp-7440    0.8684    Na-P        -6.782992
# NaP15           mp-1194653    1.4966    Na-P        -8.758255
# NaP5              mp-31086    1.3958    Na-P        -8.326953
# NaP7            mp-1195785    1.7429    Na-P        -8.513246
# NaPS3           mp-1189520    1.9880  Na-P-S        -4.699815
# NaS                mp-2400    1.2348    Na-S        -6.803380
# NaS2              mp-12180    2.0185    Na-S        -7.249936
# P                mp-568348    1.8454       P        -9.002076
# P2S             mp-1220021    0.0000     P-S        -8.441101
# P2S3              mp-29014    2.3245     P-S        -8.619234
# P2S5             mp-541788    2.5540     P-S        -8.526280
# P2S7            mp-1199938    2.1425     P-S        -8.423256
# P4S3               mp-1468    2.8693     P-S        -8.741601
# P4S5                mp-690    2.4891     P-S        -8.653893
# P4S7               mp-2650    2.7617     P-S        -8.607139
# P4S9             mp-542630    2.6490     P-S        -8.550565
# PS                  mp-612    2.4974     P-S        -8.668890
# S                    mp-77    2.7125       S        -8.034999

# %%
data_grouped = data_grouped.reset_index()

# %%
data_grouped
# Out:
#    formula_pretty material_id  band_gap chemsys  energy_per_atom
# 0              Na    mp-10172    0.0000      Na        -3.564181
# 1          Na2PS3  mp-1101885    2.6345  Na-P-S        -4.504702
# 2            Na2S      mp-648    2.4399    Na-S        -6.323377
# 3           Na2S5    mp-28127    1.7772    Na-S        -7.364454
# 4            Na3P     mp-1598    0.4033    Na-P        -5.385259
# 5          Na3P11      mp-473    1.8326    Na-P        -8.135392
# 6          Na3PS4    mp-28782    2.2919  Na-P-S        -4.368619
# 7             NaP     mp-7440    0.8684    Na-P        -6.782992
# 8           NaP15  mp-1194653    1.4966    Na-P        -8.758255
# 9            NaP5    mp-31086    1.3958    Na-P        -8.326953
# 10           NaP7  mp-1195785    1.7429    Na-P        -8.513246
# 11          NaPS3  mp-1189520    1.9880  Na-P-S        -4.699815
# 12            NaS     mp-2400    1.2348    Na-S        -6.803380
# 13           NaS2    mp-12180    2.0185    Na-S        -7.249936
# 14              P   mp-568348    1.8454       P        -9.002076
# 15            P2S  mp-1220021    0.0000     P-S        -8.441101
# 16           P2S3    mp-29014    2.3245     P-S        -8.619234
# 17           P2S5   mp-541788    2.5540     P-S        -8.526280
# 18           P2S7  mp-1199938    2.1425     P-S        -8.423256
# 19           P4S3     mp-1468    2.8693     P-S        -8.741601
# 20           P4S5      mp-690    2.4891     P-S        -8.653893
# 21           P4S7     mp-2650    2.7617     P-S        -8.607139
# 22           P4S9   mp-542630    2.6490     P-S        -8.550565
# 23             PS      mp-612    2.4974     P-S        -8.668890
# 24              S       mp-77    2.7125       S        -8.034999

# %% [markdown]
# get subsample

# %%
data_grouped[data_grouped['chemsys'] == 'Na-P']
# Out:
#    formula_pretty material_id  band_gap chemsys  energy_per_atom
# 4            Na3P     mp-1598    0.4033    Na-P        -5.385259
# 5          Na3P11      mp-473    1.8326    Na-P        -8.135392
# 7             NaP     mp-7440    0.8684    Na-P        -6.782992
# 8           NaP15  mp-1194653    1.4966    Na-P        -8.758255
# 9            NaP5    mp-31086    1.3958    Na-P        -8.326953
# 10           NaP7  mp-1195785    1.7429    Na-P        -8.513246

# %% [markdown]
# save the table

# %%
# data_grouped.to_csv('data/data.csv', index = False)

# %% [markdown]
# ### Task 6:
# - Plot the distribution of band gap values ​​for the materials of the Na-P-S chemical system presented in the table
# - Plot the bandgap vs. energy_per_atoms scatterp for materials with the band gap > 0.5

# %% [markdown]
# ### Scipy
# "SciPy provides algorithms for optimization, integration, interpolation, eigenvalue problems, algebraic equations, differential equations, statistics and many other classes of problems."
#
# [documentation](https://docs.scipy.org/doc/scipy/)

# %%
import matplotlib.pyplot as plt
import numpy as np
from pandas import pandas

from scipy.stats import linregress
from scipy.optimize import curve_fit    



def noise(x, mean = 0.0, std = 2500.0):
    y = np.random.normal(size = len(x), loc = mean, scale = std)
    return y


def parabola(x, a0 = -5.0, a1 = 100.0, a2 = 13.4):
    return a0 + a1 * x + a2 * x**2




plt.rcParams.update({'font.size': 10})
fig, (ax1, ax2) = plt.subplots(dpi = 300, figsize = (6, 3), ncols = 2)

x = np.linspace(-50, 50, 200)
y = parabola(x) + noise(x)

ax1.scatter(x, y, marker = 'o', label = 'measured', s = 3, alpha = 0.5)
ax1.plot(x, parabola(x), label = 'ideal', alpha = 0.5)


popt, pcov = curve_fit(parabola, x, y)

y_fit = parabola(x, *popt)
ax1.plot(x, y_fit, label = 'fit')

_ = ax2.hist(y - y_fit, bins = 20)

ax2.set_xlabel('Err')
ax2.set_ylabel('Count')

std = (y - y_fit).std()


ax1.fill_between(x, y_fit - std, y_fit + std, alpha = 0.25, color = 'darkred', label = '1 sigma')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()
plt.tight_layout()

# %% [markdown]
# ### About solving your homework
# Don't know how to solve the problem?
#
# - Use Google, ask stackoverflow, use LLM
#
# Don't understand a bug/error in your code?
#
# - Use Google, ask stackoverflow, use LLM
#
# Still having problems?
#
# - Ask a TA
